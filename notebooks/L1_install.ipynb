# %% [markdown]
# ## Video 1: installing spikeinterface
#
# __Plan__:
# 1. Install `spikeinterace` in a virtual enviroment using either conda or venv.
# 2. Have a look around the spikeinterface github page.
# 3. Play with features of JupyterLab
#
# __Resources__:
#
# Venv docs: https://docs.python.org/3/library/venv.html \
# Conda getting started: https://conda.io/projects/conda/en/latest/user-guide/getting-started.html
#
#
# Github page: https://github.com/SpikeInterface/spikeinterface \
# Documentation: https://spikeinterface.readthedocs.io/en/stable/

# %%
import spikeinterface.full as si

# %%
si.__version__
